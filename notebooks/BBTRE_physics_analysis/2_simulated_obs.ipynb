# %%
# %load_ext autoreload
# %autoreload 2

import xarray as xr
import pandas as pd
import numpy as np
import xgcm
from xmitgcm import open_mdsdataset
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10,6)
plt.rcParams['font.size'] = 16

from osse import *
from canyon_utils import *
from sloped_MITgcm import *

import warnings
warnings.filterwarnings('ignore', '.*.')

div_cmap = plt.get_cmap('RdBu_r')
div_cmap.set_bad(color=(0.8,0.8,0.8))

cmap = plt.get_cmap('viridis')
cmap.set_bad(color=(0.8,0.8,0.8))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Physical parameters

# %%
Γ = 0.0008613659531090722
N = np.sqrt(g*α*Γ)
θ = 1.26E-3
f = 5.3e-5

h = 230
k0 = 5.2e-5
k1 = 1.8e-3

dx = 600.
delta_t = 15.

# %% [markdown]
# ### Load dataset

# %%
data_dir = "../../MITgcm/experiments/rotated_BBTRE_canyon-tracer/run/"
ds = open_mdsdataset(data_dir,ignore_unknown_vars=True,prefix=["standardDiag"], delta_t=delta_t)
print(f"Δt = {(ds['time'][-1] - ds['time'][0]).values*1e-9/(24*60*60)} days")
ds = ds.isel(time=-1)
ds, grid = add_rotated_coords(ds, θ)
ds = add_thalweg(ds)
ds = add_background_temp(ds, Γ)
# Out:
# Δt = 450 nanoseconds days

# %%
ds = add_hab_coordinates(ds, grid, vert_coord='Zl', gridface='C')
ds['Nsq'] = -g/ρ0*ds['DRHODR'].where(ds['DRHODR']!=0.)+g*α*Γ
ds['Nsq_hab'] = hab_interp(ds['Nsq'], vert_coord='Zl')
ds['Nsq_hab_av'] = ds['Nsq_hab'].mean(['XC', 'YC'], skipna=True).compute()

# %%
ds = add_hab_coordinates(ds, grid, vert_coord='Z', gridface='C')
ds['THETA_BG_hab'] = hab_interp(ds['THETA_BG'], vert_coord='Z')

# %% [markdown]
# ### Load bathymetry and hydrography

# %%
geo_XY = xr.open_dataset("../../MITgcm/experiments/rotated_BBTRE_canyon/run/geocoords.nc").drop(["X", "Y"])
bathy = xr.open_dataset("../../data/Tozer2019_bathymetry.nc")

cdf = pd.read_csv("../../data/BBTRE_hydrography_hab-binned.csv")

# %%
cdf.head()
# Out:
#    Unnamed: 0  cast number (CTD)  cast number (HRP)  bottom pressure  \
# 0           0                 10                  9              NaN
# 1           1                 10                  9          5233.94
# 2           2                 10                  9          5233.94
# 3           3                 10                  9          5233.94
# 4           4                 10                  9          5233.94
#
#     latitude  longitude  height above bottom   salinity  temperature  \
# 0        NaN        NaN                  0.0        NaN          NaN
# 1 -21.784167   -19.4215                 50.0  34.735392     1.037595
# 2 -21.784167   -19.4215                100.0  34.735539     1.032399
# 3 -21.784167   -19.4215                150.0  34.735654     1.026601
# 4 -21.784167   -19.4215                200.0  34.735764     1.021755
#
#       sigma4  height_f above bottom           Nsq
# 0        NaN                    NaN           NaN
# 1  45.882368                   50.0 -1.700817e-08
# 2  45.882458                  100.0  1.890437e-08
# 3  45.882358                  150.0  5.956472e-09
# 4  45.882326                  200.0  4.607690e-08

# %% [markdown]
# ## Load Thurnherr's microstructure profile categorization

# %%
df = pd.read_csv("../../data/BBTRE_Stations_with_classification/1996_BBTRE_1/STATIONS.annot", dtype=str, header=19)
lines = []
for i in range(df.size):
    line = [np.float(e.strip(' ')) for e in str(df.iloc[i].values[0]).replace("\t", " ").split(" ") if len(e.strip(" "))>0]
    lines.append(line)
ndf_96 = pd.DataFrame(lines, columns=["castnum", "latitude", "longitude", "bottom pres", "bottom dep", "max depth", "canyon", "SeaBeam"])
ndf_96["year"] = 1996
ndf_96.head()
# Out:
#    castnum  latitude  longitude  bottom pres   bottom dep  max depth  canyon  \
# 0      1.0  -24.9805   -38.5352          NaN          NaN    969.923     NaN
# 1      2.0  -25.0020   -38.1853      3975.49  3913.259987   3837.170     NaN
# 2      3.0  -25.0028   -38.1848      3974.29  3912.089196   3883.520     NaN
# 3      4.0  -25.0013   -38.1855      3973.99  3911.796967   3883.520     NaN
# 4      5.0  -25.0007   -38.1858      3973.18  3911.006993   3896.690     NaN
#
#    SeaBeam  year
# 0      NaN  1996
# 1      NaN  1996
# 2      NaN  1996
# 3      NaN  1996
# 4      NaN  1996

# %%
df = pd.read_csv("../../data/BBTRE_Stations_with_classification/1997_BBTRE_2/STATIONS.annot", dtype=str, header=19)
lines = []
for i in range(df.size):
    line = [np.float(e.strip(' ')) for e in str(df.iloc[i].values[0]).replace("\t", " ").split(" ") if len(e.strip(" "))>0]
    lines.append(line)
ndf = pd.DataFrame(lines, columns=["castnum", "latitude", "longitude", "bottom pres", "bottom dep", "max depth", "canyon", "SeaBeam"])
ndf.head()
ndf["year"] = 1997

# %%
ndf = pd.concat([ndf_96, ndf])

# %% [markdown]
# ## Load microstructure data

# %%
mds_list = [xr.open_dataset(f"../../data/BBTRE{year}_microstructure_full.nc") for year in ["96", "97"]]
mds = xr.concat(mds_list, dim="year")
mds = mds.assign_coords({"year": [1996, 1997],})

# %%
bins = xr.DataArray(np.arange(2000., 0., -1.), (np.arange(2000., 0., -1.),) , dims="hab")
mds["DEPTH_hab"] = mds["BOT_DEPTH"] - mds["DEPTH"]
mds = mds.assign_coords({"DEPTH_hab":mds["DEPTH_hab"]})

def _interp(x, y, bins=None):
    return np.interp(
        bins,
        x[::-1],
        y[::-1]
    )

def _hab_interp(da):
    da_itp = xr.apply_ufunc(
        _interp,
        da["DEPTH_hab"],
        da,
        vectorize=True,
        dask='parallelized',
        input_core_dims=[["DEPTH"], ["DEPTH"]],
        output_core_dims=[["hab"]],
        output_sizes={"hab": bins.size},
        output_dtypes=[float],
        kwargs={'bins': bins.values},
    )
    da_itp = da_itp.assign_coords({"hab": bins})
    return da_itp

# %%
mds["σ4_hab"] = _hab_interp(mds["σ4"])
mds["b_hab"] = -g/ρ0*mds['σ4_hab']

mds["b_hab"] = mds['b_hab'].where(mds['b_hab'].diff('hab') != 0.)

spikes = np.abs(mds['b_hab'].diff('hab')/mds['hab'].diff('hab')) < 2.e-5
mds["b_hab"] = mds["b_hab"].where(spikes)

# %%
bin_size = 25.

def _Nfit(hab, b):
    idx = (~np.isnan(b))
    if sum(idx) > bin_size//2:
        return np.polyfit(hab[idx], b[idx], 1)[0]
    else:
        return np.nan

def Nfit(b):
    return xr.apply_ufunc(
        _Nfit, b['hab'], b, input_core_dims=[['hab'], ['hab']], vectorize=True,
    )

# %%
mds['Nsq_hab'] = mds['b_hab'].diff("hab")/mds['hab'].diff("hab")
mds['Nsq_hab'] = mds['Nsq_hab'].where(mds['Nsq_hab']!=0.).compute()


nbins = np.int64(np.ceil(mds.hab.size//bin_size))
Nsq = np.zeros((mds.year.size, mds.CAST.size, nbins))
b = np.zeros((mds.year.size, mds.CAST.size, nbins))
hab = np.arange(bin_size/2., bin_size/2. + bin_size*nbins, bin_size)
for k in range(nbins):
    b_tmp = mds['b_hab'].sel(hab=slice((k+1)*bin_size, k*bin_size))
    b[:, :, k] = b_tmp.mean("hab", skipna=True)
    Nsq[:, :, k] = Nfit(b_tmp).values;

# %%
mds_av = xr.Dataset()
mds_av["b"] = xr.DataArray(b, coords={'year':mds.year, 'CAST': mds.CAST, 'hab':hab}, dims=('year', 'CAST', 'hab',))
mds_av["Nsq"] = xr.DataArray(Nsq, coords={'year':mds.year, 'CAST': mds.CAST, 'hab':hab}, dims=('year', 'CAST', 'hab',))
mds_av["Nsq"] = mds_av["Nsq"].where(mds_av["Nsq"] > -1.e-5)

# %%
mds_av['Nsq'].mean('CAST', skipna=True).sel(year=1996).plot(y="hab", label="1996")
mds_av['Nsq'].mean('CAST', skipna=True).sel(year=1997).plot(y="hab", label="1997")
plt.legend()
plt.xlim(0, 1.5e-6)
plt.ylim(0, 2000)
plt.title("sample-averaged height-above-bottom stratification")
# Out:
# Text(0.5, 1.0, 'sample-averaged height-above-bottom stratification')

# %%
mds_av['Nsq'].mean('CAST', skipna=True).sel(year=1996).plot(y="hab", label="1996")
mds_av['Nsq'].mean('CAST', skipna=True).sel(year=1997).plot(y="hab", label="1997")
plt.legend()
plt.xscale("log")
plt.xlim(1e-7, 1.5e-6)
plt.ylim(0, 1500)
plt.title("sample-averaged height-above-bottom stratification")
# Out:
# Text(0.5, 1.0, 'sample-averaged height-above-bottom stratification')

# %% [markdown]
# # Map of hydrographic and microstructure profiles
#
# Colored by whether Thurnherr classified as "in-canyon".

# %%
plt.plot(ndf['castnum'], ndf['longitude'], "o", alpha=0.2, markersize=12)
for year in [1996, 1997]:
    plt.plot(mds['CAST'], mds['LONGITUDE'].sel(year=year), "o", markersize=7, alpha=0.4, label=f"HRP casts ({year})")
plt.plot(cdf['cast number (HRP)'], cdf['longitude'], "k.", markersize=1., label="CTD casts (1997)")
plt.legend()

# %%
plt.figure(figsize=(22,9.5))

for yi, year in enumerate([1996, 1997]):
    ax = plt.subplot(1,2,yi+1)
    if yi==0:
        q = bathy['z'].sel(lon=slice(-19, -15.5), lat=slice(-22.25, -20.75)).plot(ax=ax,x='lon', y='lat', vmin=-5500, vmax=-2500)
    if yi==1:
        q = bathy['z'].sel(lon=slice(-23, -11), lat=slice(-25.5, -20)).plot(ax=ax,x='lon', y='lat', vmin=-5500, vmax=-2500)
    q.colorbar.remove()
    geo_XY['z_actual'].plot(ax=ax, x='lon', y='lat', vmin=-5500, vmax=-2500)
    for num in np.unique(ndf['castnum']):
        cast = ndf[(ndf['castnum']==num) & (ndf["year"]==year)]
        if len(cast)>0:
            cast=cast.iloc[0]
        else:
            continue
        if cast['latitude'].dtype == 'float64':
            x = cast['longitude']
            y = cast['latitude']
            col='w'
            if np.isnan(cast['canyon']): col='r'
            ax.plot(x, y, color=col, marker="o", markersize=5)
            ax.annotate(np.int(num), # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 fontsize=12,
                 color=col,
                 ha='center'
            )
    plt.plot([],[], "wo", label="in a canyon")
    plt.title(f"Cast locations ({year})")
    plt.legend()
plt.tight_layout()

# %% [markdown]
# ### CTD casts

# %%
for yi, year in enumerate([1996, 1997], start=1):
    plt.subplot(1,2,yi)
    plt.title(f"BBTRE cruise {year}")
    in_list = np.int64(ndf[~np.isnan(ndf["canyon"]) & (ndf["year"]==year)]["castnum"])
    out_list = np.int64(ndf[np.isnan(ndf["canyon"]) & (ndf["year"]==year)]["castnum"])

    nz = 60
    in_arr = np.ones((nz, len(in_list)))*np.nan
    for i, num in enumerate(in_list):
        if num in cdf['cast number (HRP)']:
            tmp_df = cdf[cdf['cast number (HRP)']==num]
            if len(tmp_df)>0:
                pf = tmp_df['height_f above bottom']
                plt.plot(tmp_df['Nsq'], pf, "k-", alpha=0.1)
                plt.ylim([0, 1000])
                in_arr[:, i] = tmp_df['Nsq']
    plt.fill_betweenx(pf, np.nanquantile(in_arr,0.25, axis=1), np.nanquantile(in_arr, 0.75, axis=1), facecolor="k", alpha=0.2)
    plt.plot(np.nanmean(in_arr,axis=1), pf, "k-", lw=3, label="in canyon")

    out_arr = np.ones((nz, len(out_list)))*np.nan
    for i, num in enumerate(out_list):
        if num in cdf['cast number (HRP)']:
            tmp_df = cdf[cdf['cast number (HRP)']==num]
            if len(tmp_df)>0:
                pf = tmp_df['height_f above bottom']
                plt.plot(tmp_df['Nsq'], pf, "r-", alpha=0.1)
                plt.ylim([0, 1000])
                out_arr[:, i] = tmp_df['Nsq']
    plt.fill_betweenx(pf, np.nanquantile(out_arr,0.25, axis=1), np.nanquantile(out_arr,0.75, axis=1), facecolor="r", alpha=0.2)
    plt.plot(np.nanmean(out_arr,axis=1), pf, "r-", lw=3, label="outside canyon")
    plt.xscale("log")
    plt.xlim(1e-8, 2.e-6)
    plt.legend(loc="upper left")

# %%
casts = cdf['cast number (CTD)'].unique()

lons, lats = [], []
for cast in casts:
    lons.append(np.nanmedian(cdf[cdf['cast number (CTD)']==cast]['longitude'].values))
    lats.append(np.nanmedian(cdf[cdf['cast number (CTD)']==cast]['latitude'].values))

# %%
def global_argmin(da):
    xmin = da.min(dim=['Xr'])
    xargmin = da.argmin(dim='Xr').values
    yargmin = xmin.argmin(dim='Yr').values
    return [xargmin[yargmin], yargmin], xmin[yargmin].values

# %%
sample_locs = []
sample_casts = []
sample_coords = []
for c, cast in enumerate(casts):
    if np.isnan(lats[c]) | np.isnan(lons[c]): continue
    mindist = ((geo_XY['lat']-lats[c])**2 + (geo_XY['lon']-lons[c])**2)
    argmin, _ = global_argmin(mindist)
    new_cast = cdf[cdf['cast number (CTD)'] == cast]['cast number (HRP)'].values[0]
    if (
        (argmin[0] == 0) | (argmin[0] == geo_XY.dims['Xr']-1) |
        (argmin[1] == 0) | (argmin[1] == geo_XY.dims['Yr']-1)
    ):
        print(f"CTD cast {cast} / HRP {new_cast} is outside domain")
        continue
    else:
        print(f"CTD cast {cast} / HRP {new_cast} is inside domain")
    sample_locs.append(argmin)
    sample_coords.append([lons[c], lats[c]])
    sample_casts.append(new_cast)
# Out:
# CTD cast 10 / HRP 9 is outside domain
# CTD cast 11 / HRP 10 is outside domain
# CTD cast 14 / HRP 14 is inside domain
# CTD cast 15 / HRP 15 is inside domain
# CTD cast 16 / HRP 16 is inside domain
# CTD cast 18 / HRP 18 is inside domain
# CTD cast 19 / HRP 19 is inside domain
# CTD cast 21 / HRP 21 is inside domain
# CTD cast 22 / HRP 22 is inside domain
# CTD cast 23 / HRP 23 is inside domain
# CTD cast 24 / HRP 24 is inside domain
# CTD cast 25 / HRP 25 is outside domain
# CTD cast 26 / HRP 26 is outside domain
# CTD cast 27 / HRP 27 is outside domain
# CTD cast 29 / HRP 29 is outside domain
# CTD cast 30 / HRP 41 is outside domain
# CTD cast 31 / HRP 42 is outside domain
# CTD cast 32 / HRP 43 is outside domain
# CTD cast 33 / HRP 44 is outside domain
# CTD cast 34 / HRP 45 is outside domain
# CTD cast 35 / HRP 46 is outside domain
# CTD cast 36 / HRP 47 is outside domain
# CTD cast 37 / HRP 48 is outside domain
# CTD cast 38 / HRP 49 is outside domain
# CTD cast 39 / HRP 50 is outside domain
# CTD cast 40 / HRP 51 is outside domain
# CTD cast 41 / HRP 52 is outside domain
# CTD cast 42 / HRP 53 is outside domain
# CTD cast 43 / HRP 54 is outside domain
# CTD cast 44 / HRP 55 is outside domain
# CTD cast 45 / HRP 56 is outside domain
# CTD cast 46 / HRP 57 is outside domain
# CTD cast 47 / HRP 58 is outside domain
# CTD cast 48 / HRP 59 is outside domain
# CTD cast 49 / HRP 60 is outside domain
# CTD cast 50 / HRP 62 is outside domain
# CTD cast 51 / HRP 63 is outside domain
# CTD cast 52 / HRP 64 is outside domain
# CTD cast 54 / HRP 66 is outside domain
# CTD cast 55 / HRP 67 is outside domain
# CTD cast 56 / HRP 68 is outside domain
# CTD cast 57 / HRP 69 is outside domain
# CTD cast 58 / HRP 70 is outside domain
# CTD cast 59 / HRP 71 is outside domain
# CTD cast 60 / HRP 72 is outside domain
# CTD cast 61 / HRP 73 is outside domain
# CTD cast 62 / HRP 74 is outside domain
# CTD cast 63 / HRP 75 is outside domain
# CTD cast 64 / HRP 76 is outside domain
# CTD cast 65 / HRP 77 is outside domain
# CTD cast 66 / HRP 78 is outside domain
# CTD cast 67 / HRP 79 is outside domain
# CTD cast 68 / HRP 80 is outside domain
# CTD cast 69 / HRP 81 is outside domain
# CTD cast 70 / HRP 82 is outside domain
# CTD cast 71 / HRP 83 is outside domain
# CTD cast 73 / HRP 84 is outside domain
# CTD cast 74 / HRP 86 is outside domain
# CTD cast 75 / HRP 87 is outside domain
# CTD cast 76 / HRP 88 is outside domain
# CTD cast 77 / HRP 89 is outside domain
# CTD cast 78 / HRP 90 is outside domain

# %%
ds['TopographicHeight'] = ds.attrs['H']-ds['Depth']

plt.figure(figsize=(12, 15))

z_obs = -cdf[(cdf['cast number (HRP)']==sample_casts[0])]['height_f above bottom'].values
Nsq_obs_av = np.zeros(z_obs.size)

z_sim = ds['habC'].values
Nsq_sim_av = np.zeros(ds['habC'].size)

Nsamples = len(sample_casts)

for c, loc in enumerate(sample_locs):
    print(c, end=", ")
    plt.subplot(3,3,c+1)
    
    tmp = ds.isel(XC=loc[0], YC=loc[1])
    Nsq_sim_av += tmp['Nsq_hab'].values/Nsamples
    
    plt.semilogx(tmp['Nsq_hab'], tmp['habC'])
    
    tmp_df = cdf[cdf['cast number (HRP)']==sample_casts[c]]
    Nsq_obs_av += tmp_df['Nsq'].values/Nsamples
    
    plt.semilogx(tmp_df['Nsq'], -tmp_df['height_f above bottom'], '--')
    plt.ylim([0, 2000])
    plt.title(f"Cast {sample_casts[c]} ({round(sample_coords[c][0],1)}, {round(sample_coords[c][1],1)})")
    plt.xlim([3.e-9,3.e-6])
    plt.xlabel(r"stratification [s$^{-2}$]")
    plt.ylabel("depth [m]")
    
plt.tight_layout()
plt.savefig("../../figures/BBTRE/canyon_casts_comparison.png", dpi=150, bbox_inches="tight")
# Out:
# 0, 1, 2, 3, 4, 5, 6, 7, 8,

# %%
dsnap = open_mdsdataset(data_dir,ignore_unknown_vars=True,prefix=["budgetDiag"], delta_t=delta_t)
dsnap = dsnap.isel(time=-1)
dsnap, grid_snap = add_rotated_coords(dsnap, θ)
dsnap = add_thalweg(dsnap)
dsnap = add_background_temp(dsnap, Γ)

dsnap = add_hab_coordinates(dsnap, grid, vert_coord='Z', gridface='C')
dsnap['THETA_BG_hab'] = hab_interp(dsnap['THETA_BG'], vert_coord='Z')

# %%
# q10 = mds_av['Nsq_hab'].sel(year=1997, CAST=np.arange(13, 25)).quantile(0.1, dim="CAST", skipna=True)
# q90 = mds_av['Nsq_hab'].sel(year=1997, CAST=np.arange(13, 25)).quantile(0.9, dim="CAST", skipna=True)

# %%
crest_casts = np.append(np.arange(47, 54), np.arange(55, 58))
canyon_casts = np.arange(14, 25)

# %%
mds_crest_av = mds_av['Nsq'].sel(CAST=crest_casts, year=1996).mean("CAST", skipna=True)
mask_points = (np.isnan(mds_av['Nsq'].sel(CAST=crest_casts, year=1996)).mean('CAST')) <= 0.5 # mask averages with less than 50% val
mds_crest_av = mds_crest_av.where(mask_points)

mds_canyon_av = mds_av['Nsq'].sel(CAST=canyon_casts, year=1997).mean("CAST", skipna=True)
mask_points = (np.isnan(mds_av['Nsq'].sel(CAST=canyon_casts, year=1997)).mean('CAST')) <= 0.5 # mask averages with less than 50% val
mds_canyon_av = mds_canyon_av.where(mask_points)

# %%
fig = plt.figure(figsize=(21.5,6))
gs = fig.add_gridspec(1, 3)
ax1 = fig.add_subplot(gs[0, 0])

#plt.fill_betweenx(mds_av["hab"], q10, q90, alpha=0.1, facecolor="C3")

ds['Nsq_hab_av'].plot(y="habC", xscale="log", lw=2.5, color="C0", linestyle="-", label="Simulated (full domain)")
mds_crest_av.plot(y='hab', color='C0', lw=2., linestyle='--', label="HRP (on canyon crest)", alpha=0.5)

plt.axvline(N**2, alpha=0.3, linestyle="--", color="k")
plt.grid(True, alpha=0.3)

plt.semilogx(Nsq_sim_av, z_sim, "C3-", lw=2.5, label="Simulated (subsampled)")
mds_canyon_av.plot(y='hab', color='C3', linestyle="--", lw=2., label="HRP (within canyon)", alpha=0.5)
plt.semilogx(Nsq_obs_av, -z_obs, "C3:", lw=2., label="CTD (within canyon)", alpha=0.5)
plt.plot([], [], alpha=0.3, linestyle="--", color="k", label=r"$N^{2}$ (background)")
plt.xlim([5e-8, 2e-6])
plt.ylim([0, 1100])
plt.xlabel(r"stratification $\frac{d\,b}{d\,z}$ [s$^{-2}$]")
plt.ylabel("height above bottom [m]")
plt.legend(loc="upper left", fontsize=14, handlelength=1.2, labelspacing=0.175)
plt.title("a) Height above bottom-averaged stratification", fontsize=15, loc="left")
plt.title("")

ax2 = fig.add_subplot(gs[0, 1:])
PC = (geo_XY['z_actual']).plot(cbar_kwargs={'label':"seafloor elevation [m]", "orientation":"horizontal", "fraction":0.07})
PC.set_clim([-5250, -3250])
for c, loc in enumerate(sample_locs):
    x = geo_XY['Xr'].isel(Xr=loc[0]).values
    y = geo_XY['Yr'].isel(Yr=loc[1]).values
    plt.plot(x, y, "wo")
    label = f"#{sample_casts[c]}"
    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,-25), # distance from text to points (x,y)
                 color='w',
                 ha='center')
    
    # Observed profiles (MICROSTRUCTURE)
    X = mds['σ4'].sel(CAST=sample_casts[c], year=1997)
    X = (X - X.max(skipna=True))*400e3

    Y = (X.BOT_DEPTH - X.DEPTH)
    X = X.where(Y<1500.)
    Y = Y*2e1
    plt.plot(X+x,Y+y, 'w')
    
    # Observed profiles (CTD)
    tmp = cdf[cdf['cast number (HRP)']==sample_casts[c]]
    X = tmp['sigma4']
    X = (X - X.max(skipna=True))*400e3

    Y = tmp['height above bottom']
    X = X.where(Y<1500.)
    Y = Y*2e1
    plt.plot(X+x,Y+y, 'w')
    
    # Simulated profiles
    X = (ρ0*(1-α*dsnap.isel(XC=loc[0], YC=loc[1])['THETA_BG_hab']))
    X = (X - X.max(skipna=True))*400e3

    Y = X.habC
    X = X.where(Y<1500.)
    Y = Y*2e1
    plt.plot(X+x,Y+y, 'w--')
    
    
# Outside of canyon example
i=155; j=17;
x = dsnap['XC'].isel(XC=i).values
y = dsnap['YC'].isel(YC=j).values
plt.plot(x, y, "wo")
label = f"typical\ncrest profile"
plt.annotate(label, # this is the text
             (x,y), # this is the point to label
             textcoords="offset points", # how to position the text
             xytext=(0,-36), # distance from text to points (x,y)
             color='w',
             ha='center')

X = (ρ0*(1-α*dsnap.isel(XC=i, YC=j)['THETA_BG_hab']))
X = (X - X.max(skipna=True))*400e3

Y = X.habC
X = X.where(Y<1500.)
Y = Y*2e1
plt.plot(X+x,Y+y, 'w--')

plt.plot([], [], "k-", label="Observed (CTD & Microstructure)")
plt.plot([], [], "k--", label="Simulated")
plt.legend(loc="lower right", labelspacing=0.175, handlelength=1.1)
plt.title("b) Co-located observed and simulated density profiles in the BBTRE canyon", loc="left")
plt.title("")

plt.xlabel("along-canyon distance [km]")
plt.ylabel("cross-canyon distance [km]")
xticks = np.arange(0., 500., 100.)
plt.xticks(xticks*1e3, np.int64(xticks))
yticks = np.arange(0., 70., 10.)
plt.yticks(yticks*1e3, np.int64(yticks))

plt.savefig("../../figures/BBTRE/stratification_comparison.png", dpi=150, bbox_inches="tight")
