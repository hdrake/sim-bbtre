# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import dask
import xarray as xr
import xmitgcm
from xmitgcm import open_mdsdataset
from xhistogram.xarray import histogram

from matplotlib import cm
import matplotlib.colors as colors
import numpy as np

def truncate_colormap(cmap, minval=0.0, maxval=1.0, n=100):
    new_cmap = colors.LinearSegmentedColormap.from_list(
        'trunc({n},{a:.2f},{b:.2f})'.format(n=cmap.name, a=minval, b=maxval),
        cmap(np.linspace(minval, maxval, n)))
    return new_cmap

from bbl import *
from osse import *
from canyon_utils import *
from sloped_MITgcm import *

# %%
run_dedalus = False # Dedalus only works on login nodes; MITgcm analysis has to work on compute nodes.

# %%
# Constant parameters

Γ = 0.0008613659531090722
N = np.sqrt(g*α*Γ)
θ = 1.26E-3
f = -5.3e-5

h = 230
k0 = 5.2e-5
k1 = 1.8e-3

dx = 600.; dy = 600.
delta_t = 15.

# %% [markdown]
# ### Run / load 1D Dedalus simulations

# %%
T = 4800*86400
names = ['default', 'f=0', 'Pr=230']

bbl_runs = {
    'default': {},
    'f=0': {'f': 0.},
    'Pr=230': {'σ': 100.},
    'theta=0': {'θ': 0.}
}
bbl_output = {}

for name, kwargs in bbl_runs.items():
    path = f"../../data/dedalus/transient/BBTRE-{name}_{T}.nc"

    if run_dedalus:
        from bbl import *
        bbl = bbl_exp_spinup(T=T, dt=T/100., **kwargs)
        bbl_output[name] = bbl_to_ds(bbl)
        bbl_output[name].to_netcdf(path)
        
    else:
        pathstr = path.split("/")[-1]
        print(f"Loading {pathstr}")
        bbl_output[name] = xr.open_dataset(path)
# Out:
# Loading BBTRE-default_414720000.nc
# Loading BBTRE-f=0_414720000.nc
# Loading BBTRE-Pr=230_414720000.nc
# Loading BBTRE-theta=0_414720000.nc

# %%
def add_deriv_budget(ds, zroll=1):
    ds["a"] = ds["a"]/ds["a"].max()
    for label in labels.keys():
        Az = 0.5*(ds["a"][1:].values + ds["a"][:-1].values)
        ds[f"{label}_K-per-year_z"] = (
            (
                ds[f"{label}_K-per-year"]
                .rolling({"Z":zroll}).mean()
                .diff(dim="Z")/ds['Z'].diff(dim="Z")
            ) / Az
        )

# %%
labels = {
    "total_tendency_TH_truth": "LHS",
    "total_tendency_TH": "RHS",
    "diff_tendency_TH": "Mixing",
    "conv_adv_flux_anom_TH": "Mean Flow",
    "conv_vert_adv_transient_flux_TH": "Transient Eddies",
    "conv_vert_adv_standing_flux_TH": "Standing Eddies"
}

# %%
experiments = ["idealized-plane-1D", "idealized-plane", "idealized-plane-1D-Pr230", "idealized-canyon", "idealized-sill", "canyon-tracer"]

zrolls = {
    "idealized-plane-1D": 1,
    "idealized-plane-1D-Pr230": 1,
    "idealized-plane": 1,
    "idealized-canyon": 20,
    "idealized-sill": 20,
    "canyon-tracer": 20
}

data = {}
for exp in experiments:
    data[exp] = xr.open_dataset(f"../../data/BBTRE-physics/buoyancy_{exp}.nc")
    data[exp] = data[exp].sel(Z=data[exp]['Z'][:-1])
    data[exp].attrs['H'] = data[exp]['Depth'].max(skipna=True).values
    for suffix in ["", "_K-per-year", "_cumint_mSv"]:
        data[exp]["conv_vert_adv_transient_flux_TH"+suffix] = data[exp]["conv_vert_adv_flux_TH"+suffix] - data[exp]["conv_vert_adv_standing_flux_TH"+suffix]
    add_deriv_budget(data[exp], zroll=zrolls[exp])
    
    for ii, var in enumerate(labels.keys()):
        data[exp][f"{var}_K-per-year"] /= data[exp]['a']

# %% [markdown]
# #### Plotting

# %%
import matplotlib.gridspec as gridspec

def break_axes(ax1, ax2, lw=2.5):
    d = .012  # how big to make the diagonal lines in axes coordinates
    # arguments to pass to plot, just so we don't keep repeating them
    kwargs = dict(transform=ax1.transAxes, color='k', clip_on=False)
    ax1.plot((-d, +d), (-d, +d), **kwargs, lw=lw)        # top-left diagonal
    ax1.plot((1 - d, 1 + d), (-d, +d), **kwargs, lw=lw)  # top-right diagonal

    kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
    ax2.plot((-d, +d), (1 - d, 1 + d), **kwargs, lw=lw)  # bottom-left diagonal
    ax2.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs, lw=lw)  # bottom-right diagonal

# %%
cmap = truncate_colormap(cm.get_cmap('pink'),0.1,1.)

lw = 2.5
nexp = len(experiments)
fig2 = plt.figure(figsize=(13.5,9), constrained_layout=True)
gs = gridspec.GridSpec(ncols=3, nrows=4, figure=fig2)
axes2 = np.array([
    [fig2.add_subplot(gs[0, 0]), fig2.add_subplot(gs[0, 1]), fig2.add_subplot(gs[0, 2])],
    [fig2.add_subplot(gs[2:, 0]), fig2.add_subplot(gs[2:, 1]), fig2.add_subplot(gs[2:, 2])],
    [fig2.add_subplot(gs[1, 0]), fig2.add_subplot(gs[1, 1]), fig2.add_subplot(gs[1, 2])],
])

for ax in axes2[0]:
    ax.spines['bottom'].set_visible(False)
    ax.xaxis.tick_top()
    ax.tick_params(labeltop=False)
for ax in axes2[2]:
    ax.spines['top'].set_visible(False)
    ax.xaxis.tick_bottom()

fig3, axes3 = plt.subplots(2, (nexp+1)//2, figsize=(13.5,9))

plabels=["a)", "b)", "c)", "d)", "e)", "f)"]

longnames = {
    'canyon-tracer': "BBTRE",
    'idealized-sill': "Canyon+Sill",
    'idealized-canyon': "Canyon",
    'idealized-plane': "Smooth3D",
    'idealized-plane-1D': "1D",
    'idealized-plane-1D-Pr230': r"1D$_{\sigma = 230}$"
}

labels = {
    "total_tendency_TH_truth": "LHS",
    "total_tendency_TH": "RHS",
    "diff_tendency_TH": "Mixing",
    "conv_adv_flux_anom_TH": "Mean Flow",
    "conv_vert_adv_transient_flux_TH": "Transient Eddies",
    "conv_vert_adv_standing_flux_TH": "Standing Eddies",
}

int_labels = {
    "total_tendency_TH_truth": "LHS",
    "total_tendency_TH": "RHS",
    "diff_tendency_TH": "Mixing",
    "conv_adv_flux_anom_TH": "Mean Flow",
    "conv_vert_adv_transient_flux_TH": "Transient Eddies",
    "conv_vert_adv_standing_flux_TH": "Standing Eddies",
}

linecolors = ["k", "grey", "C3", "C0", "C1", "C4"]
linestyles = ["-", "--",   "-",   "-", "-",  "-"]
    
cutoffs=[50, 50, 50]

for i, (k,v) in enumerate(data.items()):
    print(k, end="\n")

    Lx, Ly = v.XC.size*dx, v.YC.size*dy
    Ly_ref = 60.e3
    cint = k0*Γ*np.cos(θ)*Ly*Lx
    cbot = k1*Γ*np.cos(θ)*Ly*Lx
    
    for ii, var in enumerate(labels.keys()):
        rolling=1
        if i>2: rolling=12
        v[f"{var}_K-per-year"].rolling({"Z": rolling}, center=True).mean().plot(ax=axes2.flatten()[i], y='Z', color=linecolors[ii], label=labels[var], linestyle=linestyles[ii], lw=lw)
        if i<=2:
            v[f"{var}_K-per-year"].plot(ax=axes2.flatten()[i+6], y='Z', color=linecolors[ii], label=labels[var], linestyle=linestyles[ii], lw=lw)
        v[f"{var}_cumint_mSv"].plot(ax=axes3.flatten()[i], y='Z', color=linecolors[ii], label=labels[var], linestyle=linestyles[ii], lw=lw)

    if i<=2:
        axes2.flatten()[i].set_xlabel(r"")
        axes2.flatten()[i+6].set_xlabel(r"warming [$^{\circ}$C/year]")
    else:
        axes2.flatten()[i].set_xlabel(r"warming [$^{\circ}$C/year]")
    
    axes2.flatten()[i].set_title(f"{plabels[i]} {longnames[k]}", fontsize=15, loc="left")
    
    axes3.flatten()[i].axvline(cint/(Γ*np.sin(θ)*Lx*Ly)*(Ly_ref*1e-3), linestyle='--', color='C3')
    axes3.flatten()[i].set_xlabel("transport [mSv]")
    axes3.flatten()[i].set_title(f"{plabels[i]} {longnames[k]}", fontsize=15, loc="left")
    if i==1:
        axes3.flatten()[i].annotate(r"$\kappa_{BG}\; L_{y}\; \cot{\theta}$", (0.58, 0.62), xycoords='axes fraction', color="C3", rotation=-90)
    axes2_xticks=np.arange(-0.5, 0.75, 0.25)
    axes2_xticklabels = np.array([-0.5, -0.25, 0, 0.25, 0.5])
    axes2_xlims=np.array([-0.5, 0.5])
    if i<=2:
        axes2.flatten()[i].set_xticks(axes2_xticks)
        axes2.flatten()[i].set_xlim(axes2_xlims)
        axes2.flatten()[i].set_xticklabels([])
        axes2.flatten()[i+6].set_xticks(axes2_xticks)
        axes2.flatten()[i+6].set_xticklabels(axes2_xticklabels)
        axes2.flatten()[i+6].set_xlim(axes2_xlims)
        
        axes3.flatten()[i].set_xticks(np.arange(-15, 20, 5))
        #axes3.flatten()[i].set_xticklabels([-10, None, 0, None, 10])
        axes3.flatten()[i].set_xlim([-17, 17])
    else:
        axes2.flatten()[i].set_xticks(axes2_xticks)
        axes2.flatten()[i].set_xlim(axes2_xlims)
        axes2.flatten()[i].set_xticklabels(axes2_xticklabels)
        #axes2.flatten()[i].set_xticks(axes2_xticks)
        #axes2.flatten()[i].set_xticklabels(np.array([None, -0.1/4, None, 0, None, 0.1/4, None]))
        #axes2.flatten()[i].set_xlim(axes2_xlims/4)
        axes3.flatten()[i].set_xlim([-22, 22])

    if i<=2:
        axes2.flatten()[i].set_ylim(cutoffs[i]+3, 2000)
        axes2.flatten()[i+6].set_ylim(0, cutoffs[i]-3)
    else:
        axes2.flatten()[i].set_ylim(0, 1500)
    axes3.flatten()[i].set_ylim([0, 2500])
    axlist = [axes2.flatten()[i], axes3.flatten()[i]]
    if i<=2: axlist.append(axes2.flatten()[i+6])
    for axi, ax in enumerate(axlist):
        ax.grid(True, alpha=0.2)
        if (i==0) | (i==3):
            ax.set_ylabel("HAMS [m]")
            if (i==0) & (axi<2):
                if axi==1: ax.plot([], [], "k:", label="Steady (1D)")
                #leg = ax.legend(loc="upper left", handlelength=1.08, labelspacing=0.12, borderpad=0.35, fontsize=14)
                leg = ax.get_legend_handles_labels()
        else:
            ax.set_ylabel("")
            ax.set_yticklabels([])
        ax.fill_between(ax.get_xlim(), [0., 0.], v['crest_HAMS'].values*np.array([1, 1]), lw=5., alpha=0.15, facecolor="grey")
        if i>2:
            ax.annotate("within\ncanyon", xy=(0.015, 0.02), xycoords="axes fraction", color=(0.3, 0.3, 0.3), fontsize=16)
            ax.annotate("above\ncanyon", xy=(0.015, 0.855), xycoords="axes fraction", color=(0.3, 0.3, 0.3), fontsize=16)

for (i, σ) in zip([0,2], [1, 230]):
    oneD = bbl_exp(k0, k1, h, N, f, θ, σ=σ)
    oneD['k'] = k_exp(k0, k1, h, oneD['zf'])
    oneD['dz'] = oneD['zf'][1:] - oneD['zf'][:-1]
    oneD['kbz_term'] = oneD['k']*oneD['bz']/(N**2 * np.sin(θ))*Ly_ref
    oneD['ψ_term'] = -np.cumsum(oneD['u']*oneD['dz'])*Ly_ref

    ax = axes3.flatten()[i]
    ax.plot(oneD['kbz_term']*1e-3, oneD['zf'], "C3:")
    ax.plot(oneD['ψ_term']*1e-3, oneD['z'], "C0:")
        
for axi, ax in enumerate(axes2[2]):
    ax.set_ylabel("")
    if axi>0: ax.set_yticklabels([])
    
for i in range(0,3):
    break_axes(axes2[0][i], axes2[2][i])
axes2[0][0].set_ylabel("")
axes3[1,0].set_ylabel("HAMS [m]")
fig3.tight_layout()

axes2[2][0].annotate(text="HAMS [m]", xy=(-0.2, 0.3), xycoords="axes fraction", rotation=90)

fig2.savefig(f"../../figures/BBTRE/D_buoyancy_budget.png", dpi=150., bbox_inches='tight')
fig3.savefig(f"../../figures/BBTRE/D_integral_buoyancy_budget.png", dpi=150., bbox_inches='tight')
# Out:
# idealized-plane-1D
# idealized-plane
# idealized-plane-1D-Pr230
# idealized-canyon
# idealized-sill
# canyon-tracer

# %%
fig = plt.figure(figsize=(3, 3))
ax = plt.subplot()
ax.legend(leg[0], leg[1], loc=0)
ax.axis('off')
plt.tight_layout()
plt.savefig(f"../../../thesis_defense/figures/D_buoyancy_budget_legend.png", dpi=150., bbox_inches="tight")

# %%
mds_list = [xr.open_dataset(f"../../data/BBTRE{year}_microstructure_full.nc") for year in ["96", "97"]]
mds = xr.concat(mds_list, dim="year")
mds = mds.assign_coords({"year": [1996, 1997],})

###
bins = xr.DataArray(np.arange(2000., 0., -1.), (np.arange(2000., 0., -1.),) , dims="hab")
mds["DEPTH_hab"] = mds["BOT_DEPTH"] - mds["DEPTH"]
mds = mds.assign_coords({"DEPTH_hab":mds["DEPTH_hab"]})

def _interp(x, y, bins=None):
    return np.interp(
        bins,
        x[::-1],
        y[::-1]
    )

def _hab_interp(da):
    da_itp = xr.apply_ufunc(
        _interp,
        da["DEPTH_hab"],
        da,
        vectorize=True,
        dask='parallelized',
        input_core_dims=[["DEPTH"], ["DEPTH"]],
        output_core_dims=[["hab"]],
        output_sizes={"hab": bins.size},
        output_dtypes=[float],
        kwargs={'bins': bins.values},
    )
    da_itp = da_itp.assign_coords({"hab": bins})
    return da_itp

###

mds["σ4_hab"] = _hab_interp(mds["σ4"])
mds["b_hab"] = -g/ρ0*mds['σ4_hab']

mds["b_hab"] = mds['b_hab'].where(mds['b_hab'].diff('hab') != 0.)

spikes = np.abs(mds['b_hab'].diff('hab')/mds['hab'].diff('hab')) < 2.e-5
mds["b_hab"] = mds["b_hab"].where(spikes)
# Out:
# <ipython-input-15-f8c83e4b8845>:18: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   da_itp = xr.apply_ufunc(

# %%
bin_size = 25.

def _Nfit(hab, b):
    idx = (~np.isnan(b))
    if sum(idx) > bin_size//2:
        return np.polyfit(hab[idx], b[idx], 1)[0]
    else:
        return np.nan

def Nfit(b):
    return xr.apply_ufunc(
        _Nfit, b['hab'], b, input_core_dims=[['hab'], ['hab']], vectorize=True,
    )

mds['Nsq_hab'] = mds['b_hab'].diff("hab")/mds['hab'].diff("hab")
mds['Nsq_hab'] = mds['Nsq_hab'].where(mds['Nsq_hab']!=0.).compute()


nbins = np.int64(np.ceil(mds.hab.size//bin_size))
Nsq = np.zeros((mds.year.size, mds.CAST.size, nbins))
b = np.zeros((mds.year.size, mds.CAST.size, nbins))
hab = np.arange(bin_size/2., bin_size/2. + bin_size*nbins, bin_size)
for k in range(nbins):
    b_tmp = mds['b_hab'].sel(hab=slice((k+1)*bin_size, k*bin_size))
    b[:, :, k] = b_tmp.mean("hab", skipna=True)
    Nsq[:, :, k] = Nfit(b_tmp).values;

# %%
mds_av = xr.Dataset()
mds_av["b"] = xr.DataArray(b, coords={'year':mds.year, 'CAST': mds.CAST, 'hab':hab}, dims=('year', 'CAST', 'hab',))
mds_av["Nsq"] = xr.DataArray(Nsq, coords={'year':mds.year, 'CAST': mds.CAST, 'hab':hab}, dims=('year', 'CAST', 'hab',))
mds_av["Nsq"] = mds_av["Nsq"].where(mds_av["Nsq"] > -1.e-5)

crest_casts = np.append(np.arange(47, 54), np.arange(55, 58))
canyon_casts = np.arange(14, 25)

mds_crest_av = mds_av['Nsq'].sel(CAST=crest_casts, year=1996).mean("CAST", skipna=True)
mask_points = (np.isnan(mds_av['Nsq'].sel(CAST=crest_casts, year=1996)).mean('CAST')) <= 0.5 # mask averages with less than 50% val
mds_crest_av = mds_crest_av.where(mask_points)

mds_canyon_av = mds_av['Nsq'].sel(CAST=canyon_casts, year=1997).mean("CAST", skipna=True)
mask_points = (np.isnan(mds_av['Nsq'].sel(CAST=canyon_casts, year=1997)).mean('CAST')) <= 0.5 # mask averages with less than 50% val
mds_canyon_av = mds_canyon_av.where(mask_points)

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 7))

expcolors = {
    'canyon-tracer': "C3",
    'idealized-sill': "C2",
    'idealized-canyon': "C1",
    'idealized-plane': "C0"
}
titles = ["Steady 1D models", "1D models at 5000 days", 'Full domain average', 'Ridge flank average', 'Canyon flanks average', 'Canyon trough average',]
labels = ['a)', 'b)', 'c)', 'd)', "e)", "f)"]
Nsq_names = ["", "_outside", "_flanks", "_trough"]

ax = axes

ticks = np.arange(0., 2.5, 0.5)
ax.set_xticks(ticks*1.e-6)
ax.set_xticklabels(ticks)

ax.set_ylim(0, 800)
ax.set_xlim([4e-8, 2.1e-6])
ax.set_xscale('log')
ax.grid(True, alpha=0.35)
plt.tight_layout(w_pad=0.4, h_pad=0.5)

mds_crest_av.plot(ax=ax, y='hab', color='k', lw=2., linestyle='-', label="Observations", alpha=0.8)

# #bbl_output['theta=0']['bz'].plot(ax=ax, y='Zl', color="grey", linestyle='--', label=r"1D$_{\theta = 0}$", lw=2., alpha=0.9)
# ax.set_title("Domain-averaged stratification", fontsize=15)
# ax.set_ylabel("Height above bottom [m]")
# ax.set_xlabel("stratification $\overline{b_{z}}^{\:^{hab}}$ [s$^{-2}$]")
# ax.legend(loc='upper left', ncol=1, handlelength=1.1, columnspacing=0.4, borderpad=0.2, handletextpad=0.25)
# fig.savefig(f"../../sim-bbtre/job_talk/D_hab_stratification_1.png", dpi=150., bbox_inches="tight")

bbl_output['default']['bz'].plot(ax=ax, y='Zl', color="grey", linestyle='-', label=r"1D", lw=2., alpha=0.9)
#bbl_output['f=0']['bz'].plot(ax=ax, y='Zl', color="grey", linestyle=':', label=r"1D$_{f=0}$", lw=2.5, alpha=0.9)
ax.set_title("Domain-averaged stratification", fontsize=15)
ax.set_ylabel("Height above bottom [m]")
ax.set_xlabel("stratification $\overline{b_{z}}^{\:^{hab}}$ [s$^{-2}$]")
ax.legend(loc='upper left', ncol=1, handlelength=1.1, columnspacing=0.4, borderpad=0.2, handletextpad=0.25)
fig.savefig(f"../../figures/job_talk/D_hab_stratification_2.png", dpi=150., bbox_inches="tight")

iplot=3

for exp in experiments:
    if (exp=='idealized-plane-1D-Pr230'): continue
    if (exp=='idealized-plane-1D'): continue
    ds = data[exp]
    ds[f'Nsq'].plot(ax=ax, y='habC', label=longnames[exp], color=expcolors[exp], lw=3.)
    ax.set_title("Domain-averaged stratification", fontsize=15)
    ax.set_ylabel("Height above bottom [m]")
    ax.set_xlabel("stratification $\overline{b_{z}}^{\:^{hab}}$ [s$^{-2}$]")
    ax.legend(loc='upper left', ncol=2, handlelength=1.1, columnspacing=0.4, borderpad=0.2, handletextpad=0.25)
    fig.savefig(f"../../figures/job_talk/D_hab_stratification_{iplot}.png", dpi=150., bbox_inches="tight")
    iplot+=1

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 7))

expcolors = {
    'canyon-tracer': "C3",
    'idealized-sill': "C2",
    'idealized-canyon': "C1",
    'idealized-plane': "C0"
}
titles = ["Steady 1D models", "1D models at 5000 days", 'Full domain average', 'Ridge flank average', 'Canyon flanks average', 'Canyon trough average',]
labels = ['a)', 'b)', 'c)', 'd)', "e)", "f)"]
Nsq_names = ["", "_outside", "_flanks", "_trough"]

ax = axes

ticks = np.arange(0., 2.5, 0.5)
ax.set_xticks(ticks*1.e-6)
ax.set_xticklabels(ticks)

ax.set_ylim(0, 800)
ax.set_xlim([4e-8, 2.1e-6])
ax.set_xscale('log')
ax.grid(True, alpha=0.35)
plt.tight_layout(w_pad=0.4, h_pad=0.5)

mds_crest_av.plot(ax=ax, y='hab', color='k', lw=2., linestyle='-', label="Observations", alpha=0.8)

iplot=3

exp="canyon-tracer"
ds = data[exp]
ds[f'Nsq'].plot(ax=ax, y='habC', label=longnames[exp], color=expcolors[exp], lw=3.)
ax.set_title("Domain-averaged stratification", fontsize=15)
ax.set_ylabel("Height above bottom [m]")
ax.set_xlabel("stratification $\overline{b_{z}}^{\:^{hab}}$ [s$^{-2}$]")
ax.legend(loc='upper left', ncol=1, handlelength=1.1, columnspacing=0.4, borderpad=0.2, handletextpad=0.25)
fig.savefig(f"../../figures/job_talk/D_hab_stratification_full-no-1D.png", dpi=150., bbox_inches="tight")

bbl_output['default']['bz'].plot(ax=ax, y='Zl', color="grey", linestyle='-', label=r"1D", lw=2., alpha=0.9)
ax.set_title("Domain-averaged stratification", fontsize=15)
ax.set_ylabel("Height above bottom [m]")
ax.set_xlabel("stratification $\overline{b_{z}}^{\:^{hab}}$ [s$^{-2}$]")
ax.legend(loc='upper left', ncol=1, handlelength=1.1, columnspacing=0.4, borderpad=0.2, handletextpad=0.25)
fig.savefig(f"../../figures/job_talk/D_hab_stratification_full.png", dpi=150., bbox_inches="tight")

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 7))

expcolors = {
    'canyon-tracer': "C3",
    'idealized-sill': "C2",
    'idealized-canyon': "C1",
    'idealized-plane': "C0"
}
titles = ["Steady 1D models", "1D models at 5000 days", 'Full domain average', 'Ridge flank average', 'Canyon flanks average', 'Canyon trough average',]
labels = ['a)', 'b)', 'c)', 'd)', "e)", "f)"]
Nsq_names = ["", "_outside", "_flanks", "_trough"]

ax = axes

ticks = np.arange(0., 2.5, 0.5)
ax.set_xticks(ticks*1.e-6)
ax.set_xticklabels(ticks)

ax.set_ylim(0, 800)
ax.set_xlim([4e-8, 2.1e-6])
ax.set_xscale('log')
ax.grid(True, alpha=0.4)
plt.tight_layout(w_pad=0.4, h_pad=0.5)

mds_canyon_av.plot(y='hab', color='k', linestyle="--", lw=2., label="Observations", alpha=0.9)

exp = "idealized-canyon"
ds = data[exp]
ds[f'Nsq_trough'].plot(ax=ax, y='habC', label="Canyon", color=expcolors[exp], lw=3.)
ax.set_title("Trough-averaged stratification", fontsize=15)
ax.set_ylabel("Height above bottom [m]")
ax.set_xlabel("stratification $\overline{b_{z}}^{\:^{hab}}$ [s$^{-2}$]")
ax.legend(loc='upper left', ncol=2, handlelength=1.1, columnspacing=0.4, borderpad=0.2, handletextpad=0.25)

ax.set_ylabel("Height above bottom [m]")
ax.set_xlabel("stratification $\overline{b_{z}}^{\:^{hab}}$ [s$^{-2}$]")
ax.legend(loc='upper left', ncol=1, handlelength=1.1, columnspacing=0.4, borderpad=0.2, handletextpad=0.25)
fig.savefig(f"../../figures/job_talk/D_hab_stratification_in-canyon.png", dpi=150., bbox_inches="tight")

exp = "idealized-sill"
ds = data[exp]
ds[f'Nsq_trough'].plot(ax=ax, y='habC', label="Canyon+Sill", color=expcolors[exp], lw=3.)
ax.set_title("Trough-averaged stratification", fontsize=15)
ax.set_ylabel("Height above bottom [m]")
ax.set_xlabel("stratification $\overline{b_{z}}^{\:^{hab}}$ [s$^{-2}$]")
ax.legend(loc='upper left', ncol=1, handlelength=1.1, columnspacing=0.4, borderpad=0.2, handletextpad=0.25)
fig.savefig(f"../../figures/job_talk/D_hab_stratification_in-canyon-sill.png", dpi=150., bbox_inches="tight")

# %%
fig, axes = plt.subplots(1, 1, figsize=(5, 7))

expcolors = {
    'canyon-tracer': "C3",
    'idealized-sill': "C2",
    'idealized-canyon': "C1",
    'idealized-plane': "C0"
}
titles = ["Steady 1D models", "1D models at 5000 days", 'Full domain average', 'Ridge flank average', 'Canyon flanks average', 'Canyon trough average',]
labels = ['a)', 'b)', 'c)', 'd)', "e)", "f)"]
Nsq_names = ["", "_outside", "_flanks", "_trough"]

ax = axes

ticks = np.arange(0., 2.5, 0.5)
ax.set_xticks(ticks*1.e-6)
ax.set_xticklabels(ticks)

ax.set_ylim(0, 800)
ax.set_xlim([4e-8, 2.1e-6])
ax.set_xscale('log')
ax.grid(True, alpha=0.25)
plt.tight_layout(w_pad=0.4, h_pad=0.5)

bbl_output['theta=0']['bz'].plot(ax=ax, y='Zl', color="grey", linestyle='--', label=r"1D$_{\theta = 0}$", lw=2., alpha=0.9)
bbl_output['default']['bz'].plot(ax=ax, y='Zl', color="grey", linestyle='-', label=r"1D", lw=2., alpha=0.9)
bbl_output['f=0']['bz'].plot(ax=ax, y='Zl', color="grey", linestyle=':', label=r"1D$_{f=0}$", lw=2.5, alpha=0.9)


iplot=3

exp = "idealized-sill"
ds = data[exp]
ds[f'Nsq_trough'].plot(ax=ax, y='habC', label=longnames[exp], color=expcolors[exp], lw=3.)
ax.set_title("Trough-averaged stratification", fontsize=15)
ax.set_ylabel("Height above bottom [m]")
ax.set_xlabel("stratification $\overline{b_{z}}^{\:^{hab}}$ [s$^{-2}$]")
ax.legend(loc='upper left', ncol=2, handlelength=1.1, columnspacing=0.4, borderpad=0.2, handletextpad=0.25)
fig.savefig(f"../../../thesis_defense/figures/D_hab_stratification_in-canyon-sill.png", dpi=150., bbox_inches="tight")
